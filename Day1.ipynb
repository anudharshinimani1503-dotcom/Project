# %%
name="Anudharshini"
age=25
CGPA=8.5
placed=False
print("student Name:",name)
print("Age:",age)
print("CGPA:",CGPA)
print("placed:",placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# student Name: Anudharshini
# Age: 25
# CGPA: 8.5
# placed: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name=["Anudharshini","ramya","ananthi","jeevi"]
name.append("flora")
marks=[50,48,80]
print(name)
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# ['Anudharshini', 'ramya', 'ananthi', 'jeevi', 'flora']
# 80
# 5
# 3

# %%
days=("Monday","Tuesday","wednesday")
print(days[1])
# Out:
# Tuesday

# %%
student={
    "name":"Arinivarishini",
    "Age":20
}
print(student)
# Out:
# {'name': 'Arinivarishini', 'Age': 20}

# %%
import numpy as np
marks=np.array([80,48,30,90])
print(marks)
# Out:
# [80 48 30 90]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([5,6,7])
print(a+b)
# Out:
# [ 6  8 10]
